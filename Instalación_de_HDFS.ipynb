# %% [markdown]
# <a href="https://colab.research.google.com/github/JOSELUISMILLA/NET8APIDEMO/blob/main/Instalaci%C3%B3n_de_HDFS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instalación de Hadoop HDFS

# %% [markdown]
# Este código está destinado a configurar un entorno Hadoop en Google Colab utilizando Python y comandos de shell. Hadoop es un framework de código abierto diseñado para procesar y almacenar grandes conjuntos de datos en clústeres de hardware. El código que has proporcionado realiza una serie de pasos para instalar, configurar y ejecutar un entorno Hadoop básico en Colab.
#
# 1. **Instalar Java:**
#    ```
#    !apt-get install openjdk-8-jdk-headless -qq > /dev/null
#    ```
#    Este comando utiliza el comando `apt-get` para instalar la versión 8 de OpenJDK (Java Development Kit) sin mostrar mensajes en la salida estándar.
#
# 2. **Descargar Hadoop:**
#    ```
#    !wget https://downloads.apache.org/hadoop/common/hadoop-3.3.1/hadoop-3.3.1.tar.gz
#    !tar -xvf hadoop-3.3.1.tar.gz
#    ```
#    Aquí, se descarga el archivo tar.gz de Hadoop 3.3.1 desde el servidor de descargas de Apache y luego se descomprime usando `tar`.
#
# 3. **Configurar variables de entorno para Colab:**
#    ```python
#    import os
#    os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
#    os.environ["HADOOP_HOME"] = "/content/hadoop-3.3.1"
#    ```
#    Se configuran las variables de entorno `JAVA_HOME` y `HADOOP_HOME` para que los comandos futuros puedan encontrar la ubicación de Java y Hadoop en el sistema.
#
# 4. **Crear un usuario falso para Hadoop:**
#    ```
#    !addgroup hadoop
#    !adduser --disabled-password --gecos '' hduser
#    !adduser hduser hadoop
#    ```
#    Aquí se crea un grupo llamado "hadoop" y un usuario llamado "hduser" dentro del grupo. Este usuario se utiliza para ejecutar procesos de Hadoop.
#
# 5. **Establecer variables de entorno HDFS para el usuario hduser:**
#    ```python
#    os.environ["HDFS_NAMENODE_USER"] = "hduser"
#    os.environ["HDFS_DATANODE_USER"] = "hduser"
#    os.environ["HDFS_SECONDARYNAMENODE_USER"] = "hduser"
#    ```
#    Se configuran variables de entorno relacionadas con los usuarios para los diferentes componentes de Hadoop.
#
# 6. **Configurar archivos XML de Hadoop:**
#    Aquí se generan y configuran los archivos de configuración de Hadoop, `core-site.xml` y `hdfs-site.xml`. Estos archivos determinan la configuración del sistema de archivos distribuido HDFS.
#
# 7. **Cambiar propiedad y permisos del directorio Hadoop:**
#    ```
#    !chown -R hduser:hadoop /content/hadoop-3.3.1
#    !chmod -R 755 /content/hadoop-3.3.1
#    ```
#    Se cambian los propietarios y permisos de los archivos y directorios de Hadoop para que el usuario "hduser" tenga acceso.
#
# 8. **Crear el directorio de registros:**
#    ```
#    !mkdir -p /content/hadoop-3.3.1/logs
#    !chown -R hduser:hadoop /content/hadoop-3.3.1/logs
#    ```
#    Se crea un directorio para los registros de Hadoop y se ajustan los permisos.
#
# 9. **Formatear el sistema de archivos HDFS:**
#    ```
#    !su - hduser -c "export JAVA_HOME=/usr/lib/jvm/java-8-openjdk-amd64 && /content/hadoop-3.3.1/bin/hdfs namenode -format"
#    ```
#    Se formatea el sistema de archivos HDFS, lo que borra todos los datos existentes y prepara el sistema para su uso.
#
# 10. **Iniciar el NameNode y DataNode manualmente:**
#     Aquí, los componentes NameNode y DataNode de Hadoop se inician en segundo plano.
#
# 11. **Crear un directorio en HDFS y listar directorios:**
#     Se crea un directorio llamado "demo" en el sistema de archivos distribuido HDFS y luego se lista el contenido del directorio raíz.
#
# 12. **Listar procesos Java en ejecución:**
#     ```
#     !su - hduser -c "jps"
#     ```
#     El comando `jps` muestra los procesos Java en ejecución, lo que permite verificar que los componentes de Hadoop estén funcionando.

# %%
# Instalar Java
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# Descargar Hadoop
# !wget -q https://dlcdn.apache.org/hadoop/common/hadoop-3.3.6/hadoop-3.3.6.tar.gz
# !tar -xvf hadoop-3.3.6.tar.gz > /dev/null

# Configurar las variables de entorno para Hadoop
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["HADOOP_HOME"] = "/content/hadoop-3.3.6"
os.environ["PATH"] += os.pathsep + os.path.join(os.environ["HADOOP_HOME"], "bin")

# Crear un usuario ficticio para Hadoop
# !addgroup hadoop
# !adduser --disabled-password --gecos '' hduser
# !adduser hduser hadoop

# Establecer variables de entorno HDFS para el usuario hduser
os.environ["HDFS_NAMENODE_USER"] = "hduser"
os.environ["HDFS_DATANODE_USER"] = "hduser"
os.environ["HDFS_SECONDARYNAMENODE_USER"] = "hduser"

# Configurar archivos XML de Hadoop
core_site_conf = """
<configuration>
  <property>
      <name>fs.defaultFS</name>
      <value>hdfs://localhost:9000</value>
  </property>
</configuration>
"""

hdfs_site_conf = """
<configuration>
  <property>
      <name>dfs.replication</name>
      <value>1</value>
  </property>
</configuration>
"""

with open("/content/hadoop-3.3.6/etc/hadoop/core-site.xml", "w") as f:
    f.write(core_site_conf)

with open("/content/hadoop-3.3.6/etc/hadoop/hdfs-site.xml", "w") as f:
    f.write(hdfs_site_conf)

# Cambiar la propiedad y permisos del directorio Hadoop
# !chown -R hduser:hadoop /content/hadoop-3.3.6
# !chmod -R 755 /content/hadoop-3.3.6

# Crear el directorio de logs
# !mkdir -p /content/hadoop-3.3.6/logs
# !chown -R hduser:hadoop /content/hadoop-3.3.6/logs

# Configurar el archivo de entorno de Hadoop
hadoop_env_conf = """
export JAVA_HOME=/usr/lib/jvm/java-8-openjdk-amd64
export HADOOP_HOME=/content/hadoop-3.3.6
export HADOOP_CONF_DIR=${HADOOP_HOME}/etc/hadoop
export PATH=${HADOOP_HOME}/bin:${PATH}
"""

with open("/content/hadoop-3.3.6/etc/hadoop/hadoop-env.sh", "w") as f:
    f.write(hadoop_env_conf)

# Formatear el sistema de archivos HDFS
# !su - hduser -c "/content/hadoop-3.3.6/bin/hdfs namenode -format"

# Iniciar el namenode de HDFS
# !su - hduser -c "/content/hadoop-3.3.6/sbin/start-dfs.sh"
# Out:
# Adding group `hadoop' (GID 1000) ...
# Done.
# Adding user `hduser' ...
# Adding new group `hduser' (1001) ...
# Adding new user `hduser' (1000) with group `hduser' ...
# Creating home directory `/home/hduser' ...
# Copying files from `/etc/skel' ...
# Adding user `hduser' to group `hadoop' ...
# Adding user hduser to group hadoop
# Done.
# 2024-08-31 23:36:42,804 INFO namenode.NameNode: STARTUP_MSG:
# /************************************************************
# STARTUP_MSG: Starting NameNode
# STARTUP_MSG:   host = f88536c420f5/172.28.0.12
# STARTUP_MSG:   args = [-format]
# STARTUP_MSG:   version = 3.3.6
# STARTUP_MSG:   classpath = /content/hadoop-3.3.6/etc/hadoop:/content/hadoop-3.3.6/share/hadoop/common/lib/netty-transport-classes-epoll-4.1.89.Final.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/jackson-core-asl-1.9.13.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/kerb-crypto-1.0.1.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/netty-handler-4.1.89.Final.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/audience-annotations-0.5.0.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/netty-common-4.1.89.Final.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/netty-transport-native-epoll-4.1.89.Final-linux-aarch_64.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/jetty-util-9.4.51.v20230217.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/kerby-pkix-1.0.1.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/jettison-1.5.4.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/javax.servlet-api-3.1.0.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/snappy-java-1.1.8.2.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/kerb-util-1.0.1.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/curator-client-5.2.0.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/guava-27.0-jre.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/jsp-api-2.1.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/nimbus-jose-jwt-9.8.1.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/commons-beanutils-1.9.4.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/kerb-core-1.0.1.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/netty-all-4.1.89.Final.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/hadoop-auth-3.3.6.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/netty-transport-4.1.89.Final.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/hadoop-annotations-3.3.6.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/jackson-core-2.12.7.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/kerb-admin-1.0.1.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/commons-net-3.9.0.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/kerby-config-1.0.1.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/avro-1.7.7.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/netty-codec-dns-4.1.89.Final.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/j2objc-annotations-1.1.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/dnsjava-2.1.7.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/netty-codec-redis-4.1.89.Final.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/jersey-server-1.19.4.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/slf4j-api-1.7.36.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/netty-codec-mqtt-4.1.89.Final.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/slf4j-reload4j-1.7.36.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/netty-transport-classes-kqueue-4.1.89.Final.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/commons-compress-1.21.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/curator-framework-5.2.0.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/jetty-http-9.4.51.v20230217.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/checker-qual-2.5.2.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/kerb-client-1.0.1.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/jsr305-3.0.2.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/netty-resolver-dns-native-macos-4.1.89.Final-osx-aarch_64.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/re2j-1.1.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/woodstox-core-5.4.0.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/commons-codec-1.15.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/commons-collections-3.2.2.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/jsr311-api-1.1.1.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/commons-math3-3.1.1.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/jakarta.activation-api-1.2.1.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/netty-codec-4.1.89.Final.jar:/content/hadoop-3.3.6 ...
# STARTUP_MSG:   build = https://github.com/apache/hadoop.git -r 1be78238728da9266a4f88195058f08fd012bf9c; compiled by 'ubuntu' on 2023-06-18T08:22Z
# STARTUP_MSG:   java = 1.8.0_422
# ************************************************************/
# 2024-08-31 23:36:42,946 INFO namenode.NameNode: registered UNIX signal handlers for [TERM, HUP, INT]
# 2024-08-31 23:36:43,261 INFO namenode.NameNode: createNameNode [-format]
# 2024-08-31 23:36:44,491 INFO namenode.NameNode: Formatting using clusterid: CID-80f5c5b3-0ddc-4a2d-a890-3a2dbdd2fc84
# 2024-08-31 23:36:44,585 INFO namenode.FSEditLog: Edit logging is async:true
# 2024-08-31 23:36:44,672 INFO namenode.FSNamesystem: KeyProvider: null
# 2024-08-31 23:36:44,685 INFO namenode.FSNamesystem: fsLock is fair: true
# 2024-08-31 23:36:44,686 INFO namenode.FSNamesystem: Detailed lock hold time metrics enabled: false
# 2024-08-31 23:36:44,696 INFO namenode.FSNamesystem: fsOwner                = hduser (auth:SIMPLE)
# 2024-08-31 23:36:44,696 INFO namenode.FSNamesystem: supergroup             = supergroup
# 2024-08-31 23:36:44,696 INFO namenode.FSNamesystem: isPermissionEnabled    = true
# 2024-08-31 23:36:44,696 INFO namenode.FSNamesystem: isStoragePolicyEnabled = true
# 2024-08-31 23:36:44,697 INFO namenode.FSNamesystem: HA Enabled: false
# 2024-08-31 23:36:44,786 INFO common.Util: dfs.datanode.fileio.profiling.sampling.percentage set to 0. Disabling file IO profiling
# 2024-08-31 23:36:45,138 INFO blockmanagement.DatanodeManager: dfs.block.invalidate.limit : configured=1000, counted=60, effected=1000
# 2024-08-31 23:36:45,139 INFO blockmanagement.DatanodeManager: dfs.namenode.datanode.registration.ip-hostname-check=true
# 2024-08-31 23:36:45,159 INFO blockmanagement.BlockManager: dfs.namenode.startup.delay.block.deletion.sec is set to 000:00:00:00.000
# 2024-08-31 23:36:45,159 INFO blockmanagement.BlockManager: The block deletion will start around 2024 Aug 31 23:36:45
# 2024-08-31 23:36:45,162 INFO util.GSet: Computing capacity for map BlocksMap
# 2024-08-31 23:36:45,162 INFO util.GSet: VM type       = 64-bit
# 2024-08-31 23:36:45,165 INFO util.GSet: 2.0% max memory 2.8 GB = 57.7 MB
# 2024-08-31 23:36:45,165 INFO util.GSet: capacity      = 2^23 = 8388608 entries
# 2024-08-31 23:36:45,182 INFO blockmanagement.BlockManager: Storage policy satisfier is disabled
# 2024-08-31 23:36:45,183 INFO blockmanagement.BlockManager: dfs.block.access.token.enable = false
# 2024-08-31 23:36:45,202 INFO blockmanagement.BlockManagerSafeMode: dfs.namenode.safemode.threshold-pct = 0.999
# 2024-08-31 23:36:45,203 INFO blockmanagement.BlockManagerSafeMode: dfs.namenode.safemode.min.datanodes = 0
# 2024-08-31 23:36:45,203 INFO blockmanagement.BlockManagerSafeMode: dfs.namenode.safemode.extension = 30000
# 2024-08-31 23:36:45,204 INFO blockmanagement.BlockManager: defaultReplication         = 1
# 2024-08-31 23:36:45,204 INFO blockmanagement.BlockManager: maxReplication             = 512
# 2024-08-31 23:36:45,204 INFO blockmanagement.BlockManager: minReplication             = 1
# 2024-08-31 23:36:45,204 INFO blockmanagement.BlockManager: maxReplicationStreams      = 2
# 2024-08-31 23:36:45,211 INFO blockmanagement.BlockManager: redundancyRecheckInterval  = 3000ms
# 2024-08-31 23:36:45,211 INFO blockmanagement.BlockManager: encryptDataTransfer        = false
# 2024-08-31 23:36:45,211 INFO blockmanagement.BlockManager: maxNumBlocksToLog          = 1000
# 2024-08-31 23:36:45,334 INFO namenode.FSDirectory: GLOBAL serial map: bits=29 maxEntries=536870911
# 2024-08-31 23:36:45,334 INFO namenode.FSDirectory: USER serial map: bits=24 maxEntries=16777215
# 2024-08-31 23:36:45,334 INFO namenode.FSDirectory: GROUP serial map: bits=24 maxEntries=16777215
# 2024-08-31 23:36:45,334 INFO namenode.FSDirectory: XATTR serial map: bits=24 maxEntries=16777215
# 2024-08-31 23:36:45,363 INFO util.GSet: Computing capacity for map INodeMap
# 2024-08-31 23:36:45,363 INFO util.GSet: VM type       = 64-bit
# 2024-08-31 23:36:45,363 INFO util.GSet: 1.0% max memory 2.8 GB = 28.9 MB
# 2024-08-31 23:36:45,363 INFO util.GSet: capacity      = 2^22 = 4194304 entries
# 2024-08-31 23:36:45,367 INFO namenode.FSDirectory: ACLs enabled? true
# 2024-08-31 23:36:45,367 INFO namenode.FSDirectory: POSIX ACL inheritance enabled? true
# 2024-08-31 23:36:45,367 INFO namenode.FSDirectory: XAttrs enabled? true
# 2024-08-31 23:36:45,368 INFO namenode.NameNode: Caching file names occurring more than 10 times
# 2024-08-31 23:36:45,377 INFO snapshot.SnapshotManager: Loaded config captureOpenFiles: false, skipCaptureAccessTimeOnlyChange: false, snapshotDiffAllowSnapRootDescendant: true, maxSnapshotLimit: 65536
# 2024-08-31 23:36:45,380 INFO snapshot.SnapshotManager: SkipList is disabled
# 2024-08-31 23:36:45,395 INFO util.GSet: Computing capacity for map cachedBlocks
# 2024-08-31 23:36:45,395 INFO util.GSet: VM type       = 64-bit
# 2024-08-31 23:36:45,396 INFO util.GSet: 0.25% max memory 2.8 GB = 7.2 MB
# 2024-08-31 23:36:45,396 INFO util.GSet: capacity      = 2^20 = 1048576 entries
# 2024-08-31 23:36:45,412 INFO metrics.TopMetrics: NNTop conf: dfs.namenode.top.window.num.buckets = 10
# 2024-08-31 23:36:45,412 INFO metrics.TopMetrics: NNTop conf: dfs.namenode.top.num.users = 10
# 2024-08-31 23:36:45,412 INFO metrics.TopMetrics: NNTop conf: dfs.namenode.top.windows.minutes = 1,5,25
# 2024-08-31 23:36:45,421 INFO namenode.FSNamesystem: Retry cache on namenode is enabled
# 2024-08-31 23:36:45,421 INFO namenode.FSNamesystem: Retry cache will use 0.03 of total heap and retry cache entry expiry time is 600000 millis
# 2024-08-31 23:36:45,424 INFO util.GSet: Computing capacity for map NameNodeRetryCache
# 2024-08-31 23:36:45,424 INFO util.GSet: VM type       = 64-bit
# 2024-08-31 23:36:45,425 INFO util.GSet: 0.029999999329447746% max memory 2.8 GB = 886.4 KB
# 2024-08-31 23:36:45,425 INFO util.GSet: capacity      = 2^17 = 131072 entries
# 2024-08-31 23:36:45,499 INFO namenode.FSImage: Allocated new BlockPoolId: BP-1460397859-172.28.0.12-1725147405475
# 2024-08-31 23:36:45,545 INFO common.Storage: Storage directory /tmp/hadoop-hduser/dfs/name has been successfully formatted.
# 2024-08-31 23:36:45,642 INFO namenode.FSImageFormatProtobuf: Saving image file /tmp/hadoop-hduser/dfs/name/current/fsimage.ckpt_0000000000000000000 using no compression
# 2024-08-31 23:36:46,063 INFO namenode.FSImageFormatProtobuf: Image file /tmp/hadoop-hduser/dfs/name/current/fsimage.ckpt_0000000000000000000 of size 401 bytes saved in 0 seconds .
# 2024-08-31 23:36:46,089 INFO namenode.NNStorageRetentionManager: Going to retain 1 images with txid >= 0
# 2024-08-31 23:36:46,167 INFO namenode.FSNamesystem: Stopping services started for active state
# 2024-08-31 23:36:46,169 INFO namenode.FSNamesystem: Stopping services started for standby state
# 2024-08-31 23:36:46,180 INFO namenode.FSImage: FSImageSaver clean checkpoint: txid=0 when meet shutdown.
# 2024-08-31 23:36:46,180 INFO namenode.NameNode: SHUTDOWN_MSG:
# /************************************************************
# SHUTDOWN_MSG: Shutting down NameNode at f88536c420f5/172.28.0.12
# ************************************************************/
# Starting namenodes on [localhost]
# localhost: ssh: connect to host localhost port 22: Cannot assign requested address
# Starting datanodes
# localhost: ssh: connect to host localhost port 22: Cannot assign requested address
# Starting secondary namenodes [f88536c420f5]
# f88536c420f5: ssh: connect to host f88536c420f5 port 22: Connection refused

# %%
# Formatear el sistema de archivos HDFS
# !su - hduser -c "export JAVA_HOME=/usr/lib/jvm/java-8-openjdk-amd64 && /content/hadoop-3.3.6/bin/hdfs namenode -format"

# Iniciar el NameNode y DataNode manualmente
# !su - hduser -c "export JAVA_HOME=/usr/lib/jvm/java-8-openjdk-amd64 && /content/hadoop-3.3.6/bin/hdfs --daemon start namenode"
# !su - hduser -c "export JAVA_HOME=/usr/lib/jvm/java-8-openjdk-amd64 && /content/hadoop-3.3.6/bin/hdfs --daemon start datanode"
# Out:
# 2024-08-31 23:36:58,030 INFO namenode.NameNode: STARTUP_MSG:
# /************************************************************
# STARTUP_MSG: Starting NameNode
# STARTUP_MSG:   host = f88536c420f5/172.28.0.12
# STARTUP_MSG:   args = [-format]
# STARTUP_MSG:   version = 3.3.6
# STARTUP_MSG:   classpath = /content/hadoop-3.3.6/etc/hadoop:/content/hadoop-3.3.6/share/hadoop/common/lib/netty-transport-classes-epoll-4.1.89.Final.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/jackson-core-asl-1.9.13.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/kerb-crypto-1.0.1.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/netty-handler-4.1.89.Final.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/audience-annotations-0.5.0.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/netty-common-4.1.89.Final.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/netty-transport-native-epoll-4.1.89.Final-linux-aarch_64.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/jetty-util-9.4.51.v20230217.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/kerby-pkix-1.0.1.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/jettison-1.5.4.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/javax.servlet-api-3.1.0.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/snappy-java-1.1.8.2.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/kerb-util-1.0.1.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/curator-client-5.2.0.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/guava-27.0-jre.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/jsp-api-2.1.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/nimbus-jose-jwt-9.8.1.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/commons-beanutils-1.9.4.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/kerb-core-1.0.1.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/netty-all-4.1.89.Final.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/hadoop-auth-3.3.6.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/netty-transport-4.1.89.Final.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/hadoop-annotations-3.3.6.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/jackson-core-2.12.7.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/kerb-admin-1.0.1.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/commons-net-3.9.0.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/kerby-config-1.0.1.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/avro-1.7.7.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/netty-codec-dns-4.1.89.Final.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/j2objc-annotations-1.1.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/dnsjava-2.1.7.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/netty-codec-redis-4.1.89.Final.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/jersey-server-1.19.4.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/slf4j-api-1.7.36.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/netty-codec-mqtt-4.1.89.Final.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/slf4j-reload4j-1.7.36.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/netty-transport-classes-kqueue-4.1.89.Final.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/commons-compress-1.21.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/curator-framework-5.2.0.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/jetty-http-9.4.51.v20230217.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/checker-qual-2.5.2.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/kerb-client-1.0.1.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/jsr305-3.0.2.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/netty-resolver-dns-native-macos-4.1.89.Final-osx-aarch_64.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/re2j-1.1.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/woodstox-core-5.4.0.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/commons-codec-1.15.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/commons-collections-3.2.2.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/jsr311-api-1.1.1.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/commons-math3-3.1.1.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/jakarta.activation-api-1.2.1.jar:/content/hadoop-3.3.6/share/hadoop/common/lib/netty-codec-4.1.89.Final.jar:/content/hadoop-3.3.6 ...
# STARTUP_MSG:   build = https://github.com/apache/hadoop.git -r 1be78238728da9266a4f88195058f08fd012bf9c; compiled by 'ubuntu' on 2023-06-18T08:22Z
# STARTUP_MSG:   java = 1.8.0_422
# ************************************************************/
# 2024-08-31 23:36:58,101 INFO namenode.NameNode: registered UNIX signal handlers for [TERM, HUP, INT]
# 2024-08-31 23:36:58,359 INFO namenode.NameNode: createNameNode [-format]
# 2024-08-31 23:36:59,215 INFO namenode.NameNode: Formatting using clusterid: CID-ae1246dd-66b1-44b6-ac5c-9b74317699dc
# 2024-08-31 23:36:59,298 INFO namenode.FSEditLog: Edit logging is async:true
# 2024-08-31 23:36:59,365 INFO namenode.FSNamesystem: KeyProvider: null
# 2024-08-31 23:36:59,369 INFO namenode.FSNamesystem: fsLock is fair: true
# 2024-08-31 23:36:59,371 INFO namenode.FSNamesystem: Detailed lock hold time metrics enabled: false
# 2024-08-31 23:36:59,380 INFO namenode.FSNamesystem: fsOwner                = hduser (auth:SIMPLE)
# 2024-08-31 23:36:59,380 INFO namenode.FSNamesystem: supergroup             = supergroup
# 2024-08-31 23:36:59,380 INFO namenode.FSNamesystem: isPermissionEnabled    = true
# 2024-08-31 23:36:59,380 INFO namenode.FSNamesystem: isStoragePolicyEnabled = true
# 2024-08-31 23:36:59,380 INFO namenode.FSNamesystem: HA Enabled: false
# 2024-08-31 23:36:59,454 INFO common.Util: dfs.datanode.fileio.profiling.sampling.percentage set to 0. Disabling file IO profiling
# 2024-08-31 23:36:59,715 INFO blockmanagement.DatanodeManager: dfs.block.invalidate.limit : configured=1000, counted=60, effected=1000
# 2024-08-31 23:36:59,715 INFO blockmanagement.DatanodeManager: dfs.namenode.datanode.registration.ip-hostname-check=true
# 2024-08-31 23:36:59,722 INFO blockmanagement.BlockManager: dfs.namenode.startup.delay.block.deletion.sec is set to 000:00:00:00.000
# 2024-08-31 23:36:59,723 INFO blockmanagement.BlockManager: The block deletion will start around 2024 Aug 31 23:36:59
# 2024-08-31 23:36:59,728 INFO util.GSet: Computing capacity for map BlocksMap
# 2024-08-31 23:36:59,728 INFO util.GSet: VM type       = 64-bit
# 2024-08-31 23:36:59,730 INFO util.GSet: 2.0% max memory 2.8 GB = 57.7 MB
# 2024-08-31 23:36:59,730 INFO util.GSet: capacity      = 2^23 = 8388608 entries
# 2024-08-31 23:36:59,751 INFO blockmanagement.BlockManager: Storage policy satisfier is disabled
# 2024-08-31 23:36:59,751 INFO blockmanagement.BlockManager: dfs.block.access.token.enable = false
# 2024-08-31 23:36:59,763 INFO blockmanagement.BlockManagerSafeMode: dfs.namenode.safemode.threshold-pct = 0.999
# 2024-08-31 23:36:59,763 INFO blockmanagement.BlockManagerSafeMode: dfs.namenode.safemode.min.datanodes = 0
# 2024-08-31 23:36:59,763 INFO blockmanagement.BlockManagerSafeMode: dfs.namenode.safemode.extension = 30000
# 2024-08-31 23:36:59,764 INFO blockmanagement.BlockManager: defaultReplication         = 1
# 2024-08-31 23:36:59,764 INFO blockmanagement.BlockManager: maxReplication             = 512
# 2024-08-31 23:36:59,764 INFO blockmanagement.BlockManager: minReplication             = 1
# 2024-08-31 23:36:59,764 INFO blockmanagement.BlockManager: maxReplicationStreams      = 2
# 2024-08-31 23:36:59,765 INFO blockmanagement.BlockManager: redundancyRecheckInterval  = 3000ms
# 2024-08-31 23:36:59,765 INFO blockmanagement.BlockManager: encryptDataTransfer        = false
# 2024-08-31 23:36:59,765 INFO blockmanagement.BlockManager: maxNumBlocksToLog          = 1000
# 2024-08-31 23:36:59,903 INFO namenode.FSDirectory: GLOBAL serial map: bits=29 maxEntries=536870911
# 2024-08-31 23:36:59,904 INFO namenode.FSDirectory: USER serial map: bits=24 maxEntries=16777215
# 2024-08-31 23:36:59,904 INFO namenode.FSDirectory: GROUP serial map: bits=24 maxEntries=16777215
# 2024-08-31 23:36:59,904 INFO namenode.FSDirectory: XATTR serial map: bits=24 maxEntries=16777215
# 2024-08-31 23:36:59,930 INFO util.GSet: Computing capacity for map INodeMap
# 2024-08-31 23:36:59,930 INFO util.GSet: VM type       = 64-bit
# 2024-08-31 23:36:59,930 INFO util.GSet: 1.0% max memory 2.8 GB = 28.9 MB
# 2024-08-31 23:36:59,930 INFO util.GSet: capacity      = 2^22 = 4194304 entries
# 2024-08-31 23:36:59,934 INFO namenode.FSDirectory: ACLs enabled? true
# 2024-08-31 23:36:59,934 INFO namenode.FSDirectory: POSIX ACL inheritance enabled? true
# 2024-08-31 23:36:59,934 INFO namenode.FSDirectory: XAttrs enabled? true
# 2024-08-31 23:36:59,935 INFO namenode.NameNode: Caching file names occurring more than 10 times
# 2024-08-31 23:36:59,945 INFO snapshot.SnapshotManager: Loaded config captureOpenFiles: false, skipCaptureAccessTimeOnlyChange: false, snapshotDiffAllowSnapRootDescendant: true, maxSnapshotLimit: 65536
# 2024-08-31 23:36:59,949 INFO snapshot.SnapshotManager: SkipList is disabled
# 2024-08-31 23:36:59,959 INFO util.GSet: Computing capacity for map cachedBlocks
# 2024-08-31 23:36:59,959 INFO util.GSet: VM type       = 64-bit
# 2024-08-31 23:36:59,959 INFO util.GSet: 0.25% max memory 2.8 GB = 7.2 MB
# 2024-08-31 23:36:59,960 INFO util.GSet: capacity      = 2^20 = 1048576 entries
# 2024-08-31 23:36:59,988 INFO metrics.TopMetrics: NNTop conf: dfs.namenode.top.window.num.buckets = 10
# 2024-08-31 23:36:59,989 INFO metrics.TopMetrics: NNTop conf: dfs.namenode.top.num.users = 10
# 2024-08-31 23:36:59,989 INFO metrics.TopMetrics: NNTop conf: dfs.namenode.top.windows.minutes = 1,5,25
# 2024-08-31 23:36:59,995 INFO namenode.FSNamesystem: Retry cache on namenode is enabled
# 2024-08-31 23:36:59,995 INFO namenode.FSNamesystem: Retry cache will use 0.03 of total heap and retry cache entry expiry time is 600000 millis
# 2024-08-31 23:36:59,998 INFO util.GSet: Computing capacity for map NameNodeRetryCache
# 2024-08-31 23:36:59,998 INFO util.GSet: VM type       = 64-bit
# 2024-08-31 23:36:59,998 INFO util.GSet: 0.029999999329447746% max memory 2.8 GB = 886.4 KB
# 2024-08-31 23:36:59,998 INFO util.GSet: capacity      = 2^17 = 131072 entries
# Re-format filesystem in Storage Directory root= /tmp/hadoop-hduser/dfs/name; location= null ? (Y or N)

# %%
# !su - hduser -c "jps"

# %% [markdown]
# Estos procesos indican que:
#
# - `NameNode`: Es el servidor maestro de HDFS que administra el sistema de archivos y facilita las operaciones a los clientes.
# - `DataNode`: Almacena los datos en el sistema Hadoop HDFS. Un sistema Hadoop típicamente tiene más de un DataNode, pero en este entorno de Colab, solo tenemos uno para simplificar.
# - `Jps`: Es una herramienta que muestra todos los procesos de Java en ejecución en la máquina.
#
# Con el `NameNode` y `DataNode` ejecutándose correctamente, HDFS está funcionando como se esperaba en tu instancia de Colab. Ahora puedes proceder con operaciones en HDFS o realizar tareas adicionales relacionadas con Hadoop que desees explorar.
